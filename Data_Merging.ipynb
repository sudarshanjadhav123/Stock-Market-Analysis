# %%
import pandas as pd

# %%
# Load CSV files into Pandas dataframes
df1 = pd.read_csv('/content/Pharmacleaned1.csv')
df2 = pd.read_csv('/content/cleanedAutomobile2.csv')
df3 = pd.read_csv('/content/cleanedFMCG.csv')
df4 = pd.read_csv('/content/cleanedIT (1).csv')

# Merge dataframes using concat function
merged_df = pd.concat([df1, df2, df3, df4])

# Write merged dataframe to a new CSV file
merged_df.to_csv('merged_file.csv', index=False)

# %%
merged_df.reset_index()
# Out:
#         index  Unnamed: 0  Unnamed: 0.1                   Sector  \
# 0           0           0           0.0  Pharmaceuticals & Drugs
# 1           1           1           1.0  Pharmaceuticals & Drugs
# 2           2           2           2.0  Pharmaceuticals & Drugs
# 3           3           3           3.0  Pharmaceuticals & Drugs
# 4           4           4           4.0  Pharmaceuticals & Drugs
# ...       ...         ...           ...                      ...
# 107535  24816       24816           NaN                       IT
# 107536  24817       24817           NaN                       IT
# 107537  24818       24818           NaN                       IT
# 107538  24819       24819           NaN                       IT
# 107539  24820       24820           NaN                       IT
#
#                          Company            BSE        Date         Open  \
# 0       Aurobindo Pharma Limited  AUROPHARMA.BO  2012-01-02    43.000000
# ...

# %%
merged_df.drop(["Unnamed: 0","Unnamed: 0.1"],axis=1,inplace=True)

# %%
merged_df
# Out:
#                         Sector                   Company            BSE  \
# 0      Pharmaceuticals & Drugs  Aurobindo Pharma Limited  AUROPHARMA.BO
# 1      Pharmaceuticals & Drugs  Aurobindo Pharma Limited  AUROPHARMA.BO
# 2      Pharmaceuticals & Drugs  Aurobindo Pharma Limited  AUROPHARMA.BO
# 3      Pharmaceuticals & Drugs  Aurobindo Pharma Limited  AUROPHARMA.BO
# 4      Pharmaceuticals & Drugs  Aurobindo Pharma Limited  AUROPHARMA.BO
# ...                        ...                       ...            ...
# 24816                       IT            TATA ELXSI LTD   TATAELXSI.BO
# 24817                       IT            TATA ELXSI LTD   TATAELXSI.BO
# 24818                       IT            TATA ELXSI LTD   TATAELXSI.BO
# 24819                       IT            TATA ELXSI LTD   TATAELXSI.BO
# 24820                       IT            TATA ELXSI LTD   TATAELXSI.BO
#
#              Date         Open         High         Low        Close  \
# ...

# %%
merged_df.reset_index()
# Out:
#         index                   Sector                   Company  \
# 0           0  Pharmaceuticals & Drugs  Aurobindo Pharma Limited
# 1           1  Pharmaceuticals & Drugs  Aurobindo Pharma Limited
# 2           2  Pharmaceuticals & Drugs  Aurobindo Pharma Limited
# 3           3  Pharmaceuticals & Drugs  Aurobindo Pharma Limited
# 4           4  Pharmaceuticals & Drugs  Aurobindo Pharma Limited
# ...       ...                      ...                       ...
# 107535  24816                       IT            TATA ELXSI LTD
# 107536  24817                       IT            TATA ELXSI LTD
# 107537  24818                       IT            TATA ELXSI LTD
# 107538  24819                       IT            TATA ELXSI LTD
# 107539  24820                       IT            TATA ELXSI LTD
#
#                   BSE        Date         Open         High         Low  \
# 0       AUROPHARMA.BO  2012-01-02    43.000000    43.450001   42.525002
# ...

# %%
merged_df.round(2)
# Out:
#                         Sector                   Company            BSE  \
# 0      Pharmaceuticals & Drugs  Aurobindo Pharma Limited  AUROPHARMA.BO
# 1      Pharmaceuticals & Drugs  Aurobindo Pharma Limited  AUROPHARMA.BO
# 2      Pharmaceuticals & Drugs  Aurobindo Pharma Limited  AUROPHARMA.BO
# 3      Pharmaceuticals & Drugs  Aurobindo Pharma Limited  AUROPHARMA.BO
# 4      Pharmaceuticals & Drugs  Aurobindo Pharma Limited  AUROPHARMA.BO
# ...                        ...                       ...            ...
# 24816                       IT            TATA ELXSI LTD   TATAELXSI.BO
# 24817                       IT            TATA ELXSI LTD   TATAELXSI.BO
# 24818                       IT            TATA ELXSI LTD   TATAELXSI.BO
# 24819                       IT            TATA ELXSI LTD   TATAELXSI.BO
# 24820                       IT            TATA ELXSI LTD   TATAELXSI.BO
#
#              Date     Open     High     Low    Close  Adj Close    Volume  \
# ...

# %%
merged_df.to_csv("Merged_Data.csv")
